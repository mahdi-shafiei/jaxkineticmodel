# %%
import tellurium as te
x=te.loadSBMLModel("BIOMD0000000244_url.xml")
# x.simulate(0,10,100)
# x.plot()
x.getNumGlobalParameters()
x.getReactionRates()

# %%
# Out:
# array([ 6.61542535e-01,  1.86937691e-01,  2.93780236e-01,  3.23345429e-01,
#         8.90005867e-02,  2.80257821e-01,  4.77273426e-01,  2.21447301e+00,
#         2.21465489e+00,  6.60721692e-04,  6.60677426e-04, -2.97139402e-08,
#        -4.96506843e-02, -4.75078176e-08,  1.56092268e-10,  1.55065539e-10,
#         1.22495518e+00,  0.00000000e+00,  4.06356981e-01,  6.69753479e-01,
#         6.69789995e-01,  3.83838063e+00,  3.55711650e+00,  3.02246727e-02,
#         5.93313836e-01,  5.93313846e-01,  3.43914772e-01,  6.18520703e-02,
#         2.73913157e-02,  2.47982093e+00,  1.95060414e+00,  6.00118426e-01,
#         1.30082365e-03,  6.82186010e-01,  9.82210146e-07,  2.94663044e-07,
#         2.94663044e-08,  0.00000000e+00,  2.27988024e-07,  2.13545819e-07,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         2.39473641e-06,  2.40247715e-06,  3.27508830e-08,  2.14123855e-07,
# ...
